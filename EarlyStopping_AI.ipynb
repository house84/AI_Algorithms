# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0add2573-ad93-4dc0-b8e2-75ec447a29c2" name="files[]" multiple disabled />
#      <output id="result-0add2573-ad93-4dc0-b8e2-75ec447a29c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ProjDataAccidentDUICategorized.csv to ProjDataAccidentDUICategorized.csv

# %%
import pandas as pd
data = pd.read_csv('ProjDataAccidentDUICategorized.csv', delimiter=',', dtype="category") 

data.head()
#print(data.dtypes)
# Out:
#   STATE PVH PERNOTMVIT  PERMVIT  ... CF3 FATALS MinutesOfDay Drunk Driver Involved
# 0     1   1           0       1  ...   0      1            2                     0
# 1     1   0           0       2  ...   0      2            1                     0
# 2     1   0           0       2  ...   0      1            1                     0
# 3     1   0           0       2  ...   0      1            3                     0
# 4     1   0           0       2  ...   0      1            2                     0
#
# [5 rows x 29 columns]

# %%
import numpy as np
dataset = np.genfromtxt('ProjDataAccidentDUICategorized.csv', delimiter=",", skip_header = True)

# %%
#Shuffle and Display
np.set_printoptions(precision = 2)
np.set_printoptions(formatter = {'int': '{: 1f}'.format})

#shuffle
#import random
#np.random.shuffle(dataset)

print(dataset.shape)
print('')
print(dataset[0:5])
# Out:
# (33654, 29)
#
# [[ 1.  1.  0.  1.  1.  5.  1.  6.  1.  1.  1.  1.  1.  0. 14.  0.  0.  1.
#    1.  0.  2.  4.  1.  0.  0.  0.  1.  2.  0.]
#  [ 1.  0.  0.  2.  2.  8.  1.  2.  1.  2.  1.  1.  1.  0. 38.  0.  1. 12.
#    1.  0.  3.  2.  2. 20.  0.  0.  2.  1.  0.]
#  [ 1.  0.  0.  2.  2.  8.  1.  2.  1.  1.  1.  1.  1.  0. 24.  0.  0.  1.
#    1.  1.  4.  2. 10.  0.  0.  0.  1.  1.  0.]
#  [ 1.  0.  0.  2.  2.  9.  1.  3.  1.  1.  1.  1.  1.  0. 24.  0.  0.  1.
#    1.  0.  4.  1. 10.  0.  0.  0.  1.  3.  0.]
#  [ 1.  0.  0.  2.  2. 19.  1.  6.  1.  2.  1.  1.  1.  0. 12.  1.  0.  1.
#    1.  0.  1.  1.  1.  0.  0.  0.  1.  2.  0.]]

# %%
#Splitting Inputs and Output
X=dataset[:,:28] #Inputs
y=dataset[:,28]  #Output
#y = np.row_stack(dataset[:,28]) #Testing 
#z = np.row_stack(dataset[:,27]) #time In Minutes
#z = dataset[:,27] #time In Minutes
print(X.shape)
print(y.shape)
#print(z.shape)
#print(z[0,0])
# Out:
# (33654, 28)
# (33654,)

# %%
#OneHotEncode Data

from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(drop='first', sparse=False)
Xenc = enc.fit(X[:,:28]).transform(X[:,:28])
print(Xenc.shape)
#print(z.shape)
#Xenc = np.append(Xenc, z, axis=1)
#print(Xenc.shape)
# Out:
# (33654, 404)

# %%
#Train Test Split and seed
from sklearn.model_selection import train_test_split
XTRAIN, XVALID, YTRAIN, YVALID = train_test_split(Xenc, y, random_state= 4300, 
test_size = .15, shuffle=True) #, stratify=y )
print(XTRAIN.shape)
print(XVALID.shape)
print(YTRAIN.shape)
print(YVALID.shape)

#Normalize test Group 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(XTRAIN)

XTRAIN = scaler.transform(XTRAIN)
XVALID = scaler.transform(XVALID)
# Out:
# (28605, 404)
# (5049, 404)
# (28605,)
# (5049,)

# %%
#Verify Shapes of XTRAIN/VALID YTRAIN/VALID
print("Training Shape: " + str(XTRAIN.shape))
print("Training Output Shape: " + str(YTRAIN.shape))
print("Validation Shape: " + str(XVALID.shape))
print("Validation Output Shape: " + str(YVALID.shape))
# Out:
# Training Shape: (28605, 404)
# Training Output Shape: (28605,)
# Validation Shape: (5049, 404)
# Validation Output Shape: (5049,)

# %%
print("Total Drunk Drivers for Training Data: " + str(sum(YTRAIN)))
print("Total Drunk Drivers for Validation Data: " + str(sum(YVALID)))
print("Total Drunk Drivers in Training and Validation: " + str(sum(YTRAIN)+sum(YVALID)))
print("Total Drunk Drivers from Original Dataset: " +str(sum(dataset[:,28])))
print()
ratio = (100*(1-8379/33654))
print("Percent of the incidents not involving a drunk driver %.2f%%" % ratio)
# Out:
# Total Drunk Drivers for Training Data: 7129.0
# Total Drunk Drivers for Validation Data: 1250.0
# Total Drunk Drivers in Training and Validation: 8379.0
# Total Drunk Drivers from Original Dataset: 8379.0
#
# Percent of the incidents not involving a drunk driver 75.10%

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.metrics import categorical_accuracy
from keras.optimizers import SGD
from keras.optimizers import adam
from keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential()
model.add(Dense(10, input_dim = 404, kernel_initializer='normal', activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

callback_a = ModelCheckpoint(filepath= 'project.hdf5', monitor='val_loss', save_best_only = True, save_weights_only = True, verbose = 1)
callback_b = EarlyStopping(monitor = 'val_loss', mode = 'min', patience = 50, verbose=1)

history = model.fit(XTRAIN, YTRAIN, batch_size=23000, epochs=1000, verbose=1, validation_data=(XVALID, YVALID), callbacks=[callback_a, callback_b]) #, shuffle=True)
# Out:
# Epoch 1/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9568 - binary_accuracy: 0.2532
# Epoch 00001: val_loss improved from inf to 0.94501, saving model to project.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9552 - binary_accuracy: 0.2535 - val_loss: 0.9450 - val_binary_accuracy: 0.2501
# Epoch 2/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9449 - binary_accuracy: 0.2534
# Epoch 00002: val_loss improved from 0.94501 to 0.93354, saving model to project.hdf5
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9430 - binary_accuracy: 0.2533 - val_loss: 0.9335 - val_binary_accuracy: 0.2507
# Epoch 3/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9339 - binary_accuracy: 0.2521
# Epoch 00003: val_loss improved from 0.93354 to 0.92246, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9305 - binary_accuracy: 0.2534 - val_loss: 0.9225 - val_binary_accuracy: 0.2515
# Epoch 4/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9222 - binary_accuracy: 0.2544
# Epoch 00004: val_loss improved from 0.92246 to 0.91178, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9204 - binary_accuracy: 0.2539 - val_loss: 0.9118 - val_binary_accuracy: 0.2517
# Epoch 5/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9116 - binary_accuracy: 0.2542
# Epoch 00005: val_loss improved from 0.91178 to 0.90148, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9095 - binary_accuracy: 0.2547 - val_loss: 0.9015 - val_binary_accuracy: 0.2541
# Epoch 6/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9018 - binary_accuracy: 0.2558
# Epoch 00006: val_loss improved from 0.90148 to 0.89147, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8980 - binary_accuracy: 0.2557 - val_loss: 0.8915 - val_binary_accuracy: 0.2547
# Epoch 7/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8908 - binary_accuracy: 0.2586
# Epoch 00007: val_loss improved from 0.89147 to 0.88176, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8896 - binary_accuracy: 0.2574 - val_loss: 0.8818 - val_binary_accuracy: 0.2563
# Epoch 8/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8828 - binary_accuracy: 0.2588
# Epoch 00008: val_loss improved from 0.88176 to 0.87236, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8771 - binary_accuracy: 0.2601 - val_loss: 0.8724 - val_binary_accuracy: 0.2593
# Epoch 9/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8726 - binary_accuracy: 0.2627
# Epoch 00009: val_loss improved from 0.87236 to 0.86325, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8687 - binary_accuracy: 0.2631 - val_loss: 0.8632 - val_binary_accuracy: 0.2648
# Epoch 10/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8628 - binary_accuracy: 0.2667
# Epoch 00010: val_loss improved from 0.86325 to 0.85443, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8605 - binary_accuracy: 0.2673 - val_loss: 0.8544 - val_binary_accuracy: 0.2696
# Epoch 11/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8534 - binary_accuracy: 0.2721
# Epoch 00011: val_loss improved from 0.85443 to 0.84588, saving model to project.hdf5
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8523 - binary_accuracy: 0.2727 - val_loss: 0.8459 - val_binary_accuracy: 0.2775
# Epoch 12/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8470 - binary_accuracy: 0.2753
# Epoch 00012: val_loss improved from 0.84588 to 0.83758, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8404 - binary_accuracy: 0.2808 - val_loss: 0.8376 - val_binary_accuracy: 0.2870
# Epoch 13/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8384 - binary_accuracy: 0.2862
# Epoch 00013: val_loss improved from 0.83758 to 0.82956, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8323 - binary_accuracy: 0.2899 - val_loss: 0.8296 - val_binary_accuracy: 0.3009
# Epoch 14/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8284 - binary_accuracy: 0.3017
# Epoch 00014: val_loss improved from 0.82956 to 0.82176, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8270 - binary_accuracy: 0.3013 - val_loss: 0.8218 - val_binary_accuracy: 0.3137
# Epoch 15/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8206 - binary_accuracy: 0.3143
# Epoch 00015: val_loss improved from 0.82176 to 0.81418, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8191 - binary_accuracy: 0.3142 - val_loss: 0.8142 - val_binary_accuracy: 0.3268
# Epoch 16/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8138 - binary_accuracy: 0.3247
# Epoch 00016: val_loss improved from 0.81418 to 0.80683, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8099 - binary_accuracy: 0.3271 - val_loss: 0.8068 - val_binary_accuracy: 0.3403
# Epoch 17/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8066 - binary_accuracy: 0.3388
# Epoch 00017: val_loss improved from 0.80683 to 0.79969, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8020 - binary_accuracy: 0.3410 - val_loss: 0.7997 - val_binary_accuracy: 0.3543
# Epoch 18/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7965 - binary_accuracy: 0.3557
# Epoch 00018: val_loss improved from 0.79969 to 0.79275, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7992 - binary_accuracy: 0.3564 - val_loss: 0.7928 - val_binary_accuracy: 0.3698
# Epoch 19/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7909 - binary_accuracy: 0.3695
# Epoch 00019: val_loss improved from 0.79275 to 0.78600, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7898 - binary_accuracy: 0.3716 - val_loss: 0.7860 - val_binary_accuracy: 0.3832
# Epoch 20/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7830 - binary_accuracy: 0.3863
# Epoch 00020: val_loss improved from 0.78600 to 0.77943, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7845 - binary_accuracy: 0.3862 - val_loss: 0.7794 - val_binary_accuracy: 0.3969
# Epoch 21/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7771 - binary_accuracy: 0.4012
# Epoch 00021: val_loss improved from 0.77943 to 0.77301, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7765 - binary_accuracy: 0.4010 - val_loss: 0.7730 - val_binary_accuracy: 0.4112
# Epoch 22/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7714 - binary_accuracy: 0.4123
# Epoch 00022: val_loss improved from 0.77301 to 0.76674, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7686 - binary_accuracy: 0.4145 - val_loss: 0.7667 - val_binary_accuracy: 0.4221
# Epoch 23/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7647 - binary_accuracy: 0.4257
# Epoch 00023: val_loss improved from 0.76674 to 0.76062, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7626 - binary_accuracy: 0.4280 - val_loss: 0.7606 - val_binary_accuracy: 0.4334
# Epoch 24/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7583 - binary_accuracy: 0.4395
# Epoch 00024: val_loss improved from 0.76062 to 0.75466, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7565 - binary_accuracy: 0.4411 - val_loss: 0.7547 - val_binary_accuracy: 0.4456
# Epoch 25/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7517 - binary_accuracy: 0.4540
# Epoch 00025: val_loss improved from 0.75466 to 0.74881, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7513 - binary_accuracy: 0.4540 - val_loss: 0.7488 - val_binary_accuracy: 0.4581
# Epoch 26/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7472 - binary_accuracy: 0.4650
# Epoch 00026: val_loss improved from 0.74881 to 0.74308, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7430 - binary_accuracy: 0.4671 - val_loss: 0.7431 - val_binary_accuracy: 0.4686
# Epoch 27/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7402 - binary_accuracy: 0.4792
# Epoch 00027: val_loss improved from 0.74308 to 0.73750, saving model to project.hdf5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7389 - binary_accuracy: 0.4796 - val_loss: 0.7375 - val_binary_accuracy: 0.4795
# Epoch 28/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7331 - binary_accuracy: 0.4920
# Epoch 00028: val_loss improved from 0.73750 to 0.73204, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7353 - binary_accuracy: 0.4908 - val_loss: 0.7320 - val_binary_accuracy: 0.4914
# Epoch 29/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7284 - binary_accuracy: 0.5023
# Epoch 00029: val_loss improved from 0.73204 to 0.72670, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7282 - binary_accuracy: 0.5022 - val_loss: 0.7267 - val_binary_accuracy: 0.5011
# Epoch 30/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7232 - binary_accuracy: 0.5117
# Epoch 00030: val_loss improved from 0.72670 to 0.72149, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7222 - binary_accuracy: 0.5140 - val_loss: 0.7215 - val_binary_accuracy: 0.5108
# Epoch 31/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7178 - binary_accuracy: 0.5240
# Epoch 00031: val_loss improved from 0.72149 to 0.71639, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7168 - binary_accuracy: 0.5246 - val_loss: 0.7164 - val_binary_accuracy: 0.5260
# Epoch 32/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7120 - binary_accuracy: 0.5353
# Epoch 00032: val_loss improved from 0.71639 to 0.71137, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7123 - binary_accuracy: 0.5341 - val_loss: 0.7114 - val_binary_accuracy: 0.5361
# Epoch 33/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7079 - binary_accuracy: 0.5429
# Epoch 00033: val_loss improved from 0.71137 to 0.70643, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7056 - binary_accuracy: 0.5451 - val_loss: 0.7064 - val_binary_accuracy: 0.5455
# Epoch 34/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7023 - binary_accuracy: 0.5535
# Epoch 00034: val_loss improved from 0.70643 to 0.70159, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7012 - binary_accuracy: 0.5541 - val_loss: 0.7016 - val_binary_accuracy: 0.5534
# Epoch 35/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6969 - binary_accuracy: 0.5607
# Epoch 00035: val_loss improved from 0.70159 to 0.69681, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6968 - binary_accuracy: 0.5618 - val_loss: 0.6968 - val_binary_accuracy: 0.5639
# Epoch 36/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6924 - binary_accuracy: 0.5696
# Epoch 00036: val_loss improved from 0.69681 to 0.69210, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6914 - binary_accuracy: 0.5710 - val_loss: 0.6921 - val_binary_accuracy: 0.5716
# Epoch 37/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6879 - binary_accuracy: 0.5778
# Epoch 00037: val_loss improved from 0.69210 to 0.68746, saving model to project.hdf5
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6862 - binary_accuracy: 0.5799 - val_loss: 0.6875 - val_binary_accuracy: 0.5789
# Epoch 38/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6829 - binary_accuracy: 0.5882
# Epoch 00038: val_loss improved from 0.68746 to 0.68292, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6819 - binary_accuracy: 0.5881 - val_loss: 0.6829 - val_binary_accuracy: 0.5882
# Epoch 39/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6783 - binary_accuracy: 0.5939
# Epoch 00039: val_loss improved from 0.68292 to 0.67846, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6773 - binary_accuracy: 0.5954 - val_loss: 0.6785 - val_binary_accuracy: 0.5950
# Epoch 40/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6732 - binary_accuracy: 0.6037
# Epoch 00040: val_loss improved from 0.67846 to 0.67407, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6737 - binary_accuracy: 0.6032 - val_loss: 0.6741 - val_binary_accuracy: 0.6017
# Epoch 41/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6699 - binary_accuracy: 0.6084
# Epoch 00041: val_loss improved from 0.67407 to 0.66974, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6674 - binary_accuracy: 0.6110 - val_loss: 0.6697 - val_binary_accuracy: 0.6080
# Epoch 42/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6648 - binary_accuracy: 0.6193
# Epoch 00042: val_loss improved from 0.66974 to 0.66552, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6642 - binary_accuracy: 0.6187 - val_loss: 0.6655 - val_binary_accuracy: 0.6197
# Epoch 43/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6610 - binary_accuracy: 0.6247
# Epoch 00043: val_loss improved from 0.66552 to 0.66138, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6593 - binary_accuracy: 0.6259 - val_loss: 0.6614 - val_binary_accuracy: 0.6251
# Epoch 44/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6557 - binary_accuracy: 0.6348
# Epoch 00044: val_loss improved from 0.66138 to 0.65734, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6568 - binary_accuracy: 0.6330 - val_loss: 0.6573 - val_binary_accuracy: 0.6332
# Epoch 45/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6521 - binary_accuracy: 0.6399
# Epoch 00045: val_loss improved from 0.65734 to 0.65336, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6520 - binary_accuracy: 0.6382 - val_loss: 0.6534 - val_binary_accuracy: 0.6419
# Epoch 46/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6491 - binary_accuracy: 0.6419
# Epoch 00046: val_loss improved from 0.65336 to 0.64947, saving model to project.hdf5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6464 - binary_accuracy: 0.6442 - val_loss: 0.6495 - val_binary_accuracy: 0.6443
# Epoch 47/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6435 - binary_accuracy: 0.6525
# Epoch 00047: val_loss improved from 0.64947 to 0.64567, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6450 - binary_accuracy: 0.6522 - val_loss: 0.6457 - val_binary_accuracy: 0.6508
# Epoch 48/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6412 - binary_accuracy: 0.6559
# Epoch 00048: val_loss improved from 0.64567 to 0.64195, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6388 - binary_accuracy: 0.6570 - val_loss: 0.6419 - val_binary_accuracy: 0.6534
# Epoch 49/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6363 - binary_accuracy: 0.6619
# Epoch 00049: val_loss improved from 0.64195 to 0.63829, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6368 - binary_accuracy: 0.6612 - val_loss: 0.6383 - val_binary_accuracy: 0.6587
# Epoch 50/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6342 - binary_accuracy: 0.6642
# Epoch 00050: val_loss improved from 0.63829 to 0.63471, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6306 - binary_accuracy: 0.6673 - val_loss: 0.6347 - val_binary_accuracy: 0.6639
# Epoch 51/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6308 - binary_accuracy: 0.6705
# Epoch 00051: val_loss improved from 0.63471 to 0.63119, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6267 - binary_accuracy: 0.6727 - val_loss: 0.6312 - val_binary_accuracy: 0.6692
# Epoch 52/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6250 - binary_accuracy: 0.6792
# Epoch 00052: val_loss improved from 0.63119 to 0.62776, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6265 - binary_accuracy: 0.6774 - val_loss: 0.6278 - val_binary_accuracy: 0.6746
# Epoch 53/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6215 - binary_accuracy: 0.6810
# Epoch 00053: val_loss improved from 0.62776 to 0.62437, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6231 - binary_accuracy: 0.6814 - val_loss: 0.6244 - val_binary_accuracy: 0.6789
# Epoch 54/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6194 - binary_accuracy: 0.6845
# Epoch 00054: val_loss improved from 0.62437 to 0.62104, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6176 - binary_accuracy: 0.6854 - val_loss: 0.6210 - val_binary_accuracy: 0.6825
# Epoch 55/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6163 - binary_accuracy: 0.6870
# Epoch 00055: val_loss improved from 0.62104 to 0.61777, saving model to project.hdf5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6140 - binary_accuracy: 0.6888 - val_loss: 0.6178 - val_binary_accuracy: 0.6871
# Epoch 56/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6129 - binary_accuracy: 0.6923
# Epoch 00056: val_loss improved from 0.61777 to 0.61457, saving model to project.hdf5
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6108 - binary_accuracy: 0.6928 - val_loss: 0.6146 - val_binary_accuracy: 0.6914
# Epoch 57/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6102 - binary_accuracy: 0.6953
# Epoch 00057: val_loss improved from 0.61457 to 0.61143, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6069 - binary_accuracy: 0.6970 - val_loss: 0.6114 - val_binary_accuracy: 0.6956
# Epoch 58/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6060 - binary_accuracy: 0.7001
# Epoch 00058: val_loss improved from 0.61143 to 0.60833, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6054 - binary_accuracy: 0.7003 - val_loss: 0.6083 - val_binary_accuracy: 0.6988
# Epoch 59/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6020 - binary_accuracy: 0.7047
# Epoch 00059: val_loss improved from 0.60833 to 0.60530, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6037 - binary_accuracy: 0.7029 - val_loss: 0.6053 - val_binary_accuracy: 0.7021
# Epoch 60/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6001 - binary_accuracy: 0.7050
# Epoch 00060: val_loss improved from 0.60530 to 0.60233, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5989 - binary_accuracy: 0.7056 - val_loss: 0.6023 - val_binary_accuracy: 0.7051
# Epoch 61/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5962 - binary_accuracy: 0.7117
# Epoch 00061: val_loss improved from 0.60233 to 0.59942, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5974 - binary_accuracy: 0.7097 - val_loss: 0.5994 - val_binary_accuracy: 0.7094
# Epoch 62/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5942 - binary_accuracy: 0.7133
# Epoch 00062: val_loss improved from 0.59942 to 0.59655, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5931 - binary_accuracy: 0.7134 - val_loss: 0.5966 - val_binary_accuracy: 0.7138
# Epoch 63/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5909 - binary_accuracy: 0.7171
# Epoch 00063: val_loss improved from 0.59655 to 0.59376, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5910 - binary_accuracy: 0.7172 - val_loss: 0.5938 - val_binary_accuracy: 0.7180
# Epoch 64/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5892 - binary_accuracy: 0.7207
# Epoch 00064: val_loss improved from 0.59376 to 0.59103, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5865 - binary_accuracy: 0.7204 - val_loss: 0.5910 - val_binary_accuracy: 0.7201
# Epoch 65/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5843 - binary_accuracy: 0.7259
# Epoch 00065: val_loss improved from 0.59103 to 0.58836, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5871 - binary_accuracy: 0.7232 - val_loss: 0.5884 - val_binary_accuracy: 0.7201
# Epoch 66/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5850 - binary_accuracy: 0.7235
# Epoch 00066: val_loss improved from 0.58836 to 0.58574, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5792 - binary_accuracy: 0.7257 - val_loss: 0.5857 - val_binary_accuracy: 0.7213
# Epoch 67/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5810 - binary_accuracy: 0.7278
# Epoch 00067: val_loss improved from 0.58574 to 0.58317, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5787 - binary_accuracy: 0.7281 - val_loss: 0.5832 - val_binary_accuracy: 0.7243
# Epoch 68/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5769 - binary_accuracy: 0.7307
# Epoch 00068: val_loss improved from 0.58317 to 0.58065, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5785 - binary_accuracy: 0.7298 - val_loss: 0.5807 - val_binary_accuracy: 0.7273
# Epoch 69/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5745 - binary_accuracy: 0.7333
# Epoch 00069: val_loss improved from 0.58065 to 0.57820, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5759 - binary_accuracy: 0.7324 - val_loss: 0.5782 - val_binary_accuracy: 0.7295
# Epoch 70/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5721 - binary_accuracy: 0.7346
# Epoch 00070: val_loss improved from 0.57820 to 0.57581, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5733 - binary_accuracy: 0.7344 - val_loss: 0.5758 - val_binary_accuracy: 0.7295
# Epoch 71/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5704 - binary_accuracy: 0.7370
# Epoch 00071: val_loss improved from 0.57581 to 0.57348, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5697 - binary_accuracy: 0.7360 - val_loss: 0.5735 - val_binary_accuracy: 0.7324
# Epoch 72/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5669 - binary_accuracy: 0.7396
# Epoch 00072: val_loss improved from 0.57348 to 0.57119, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5692 - binary_accuracy: 0.7384 - val_loss: 0.5712 - val_binary_accuracy: 0.7340
# Epoch 73/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5670 - binary_accuracy: 0.7379
# Epoch 00073: val_loss improved from 0.57119 to 0.56895, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5631 - binary_accuracy: 0.7405 - val_loss: 0.5689 - val_binary_accuracy: 0.7360
# Epoch 74/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5634 - binary_accuracy: 0.7416
# Epoch 00074: val_loss improved from 0.56895 to 0.56676, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5629 - binary_accuracy: 0.7420 - val_loss: 0.5668 - val_binary_accuracy: 0.7386
# Epoch 75/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5616 - binary_accuracy: 0.7436
# Epoch 00075: val_loss improved from 0.56676 to 0.56461, saving model to project.hdf5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5602 - binary_accuracy: 0.7437 - val_loss: 0.5646 - val_binary_accuracy: 0.7425
# Epoch 76/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5583 - binary_accuracy: 0.7458
# Epoch 00076: val_loss improved from 0.56461 to 0.56251, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5599 - binary_accuracy: 0.7448 - val_loss: 0.5625 - val_binary_accuracy: 0.7451
# Epoch 77/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5571 - binary_accuracy: 0.7451
# Epoch 00077: val_loss improved from 0.56251 to 0.56044, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5562 - binary_accuracy: 0.7460 - val_loss: 0.5604 - val_binary_accuracy: 0.7463
# Epoch 78/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5537 - binary_accuracy: 0.7493
# Epoch 00078: val_loss improved from 0.56044 to 0.55842, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5562 - binary_accuracy: 0.7484 - val_loss: 0.5584 - val_binary_accuracy: 0.7489
# Epoch 79/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5538 - binary_accuracy: 0.7486
# Epoch 00079: val_loss improved from 0.55842 to 0.55647, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5510 - binary_accuracy: 0.7505 - val_loss: 0.5565 - val_binary_accuracy: 0.7493
# Epoch 80/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5502 - binary_accuracy: 0.7527
# Epoch 00080: val_loss improved from 0.55647 to 0.55455, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5516 - binary_accuracy: 0.7521 - val_loss: 0.5546 - val_binary_accuracy: 0.7493
# Epoch 81/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5492 - binary_accuracy: 0.7531
# Epoch 00081: val_loss improved from 0.55455 to 0.55268, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5482 - binary_accuracy: 0.7535 - val_loss: 0.5527 - val_binary_accuracy: 0.7506
# Epoch 82/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5469 - binary_accuracy: 0.7555
# Epoch 00082: val_loss improved from 0.55268 to 0.55084, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5469 - binary_accuracy: 0.7555 - val_loss: 0.5508 - val_binary_accuracy: 0.7522
# Epoch 83/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5461 - binary_accuracy: 0.7550
# Epoch 00083: val_loss improved from 0.55084 to 0.54905, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5434 - binary_accuracy: 0.7572 - val_loss: 0.5490 - val_binary_accuracy: 0.7538
# Epoch 84/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5420 - binary_accuracy: 0.7597
# Epoch 00084: val_loss improved from 0.54905 to 0.54728, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5451 - binary_accuracy: 0.7579 - val_loss: 0.5473 - val_binary_accuracy: 0.7566
# Epoch 85/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5421 - binary_accuracy: 0.7582
# Epoch 00085: val_loss improved from 0.54728 to 0.54554, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5406 - binary_accuracy: 0.7596 - val_loss: 0.5455 - val_binary_accuracy: 0.7580
# Epoch 86/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5401 - binary_accuracy: 0.7599
# Epoch 00086: val_loss improved from 0.54554 to 0.54382, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5392 - binary_accuracy: 0.7604 - val_loss: 0.5438 - val_binary_accuracy: 0.7584
# Epoch 87/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5379 - binary_accuracy: 0.7619
# Epoch 00087: val_loss improved from 0.54382 to 0.54215, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5382 - binary_accuracy: 0.7614 - val_loss: 0.5422 - val_binary_accuracy: 0.7590
# Epoch 88/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5354 - binary_accuracy: 0.7644
# Epoch 00088: val_loss improved from 0.54215 to 0.54053, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5379 - binary_accuracy: 0.7624 - val_loss: 0.5405 - val_binary_accuracy: 0.7617
# Epoch 89/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5343 - binary_accuracy: 0.7633
# Epoch 00089: val_loss improved from 0.54053 to 0.53894, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5354 - binary_accuracy: 0.7633 - val_loss: 0.5389 - val_binary_accuracy: 0.7637
# Epoch 90/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5344 - binary_accuracy: 0.7617
# Epoch 00090: val_loss improved from 0.53894 to 0.53738, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5312 - binary_accuracy: 0.7646 - val_loss: 0.5374 - val_binary_accuracy: 0.7649
# Epoch 91/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5318 - binary_accuracy: 0.7642
# Epoch 00091: val_loss improved from 0.53738 to 0.53585, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5313 - binary_accuracy: 0.7661 - val_loss: 0.5359 - val_binary_accuracy: 0.7665
# Epoch 92/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5308 - binary_accuracy: 0.7659
# Epoch 00092: val_loss improved from 0.53585 to 0.53436, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5289 - binary_accuracy: 0.7674 - val_loss: 0.5344 - val_binary_accuracy: 0.7665
# Epoch 93/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5281 - binary_accuracy: 0.7701
# Epoch 00093: val_loss improved from 0.53436 to 0.53289, saving model to project.hdf5
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5293 - binary_accuracy: 0.7685 - val_loss: 0.5329 - val_binary_accuracy: 0.7669
# Epoch 94/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5288 - binary_accuracy: 0.7679
# Epoch 00094: val_loss improved from 0.53289 to 0.53144, saving model to project.hdf5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5246 - binary_accuracy: 0.7693 - val_loss: 0.5314 - val_binary_accuracy: 0.7693
# Epoch 95/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5247 - binary_accuracy: 0.7721
# Epoch 00095: val_loss improved from 0.53144 to 0.53003, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5273 - binary_accuracy: 0.7705 - val_loss: 0.5300 - val_binary_accuracy: 0.7699
# Epoch 96/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5235 - binary_accuracy: 0.7737
# Epoch 00096: val_loss improved from 0.53003 to 0.52866, saving model to project.hdf5
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5255 - binary_accuracy: 0.7714 - val_loss: 0.5287 - val_binary_accuracy: 0.7704
# Epoch 97/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5236 - binary_accuracy: 0.7709
# Epoch 00097: val_loss improved from 0.52866 to 0.52730, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5220 - binary_accuracy: 0.7723 - val_loss: 0.5273 - val_binary_accuracy: 0.7708
# Epoch 98/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5215 - binary_accuracy: 0.7730
# Epoch 00098: val_loss improved from 0.52730 to 0.52598, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5218 - binary_accuracy: 0.7730 - val_loss: 0.5260 - val_binary_accuracy: 0.7714
# Epoch 99/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5191 - binary_accuracy: 0.7756
# Epoch 00099: val_loss improved from 0.52598 to 0.52469, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5222 - binary_accuracy: 0.7735 - val_loss: 0.5247 - val_binary_accuracy: 0.7718
# Epoch 100/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5201 - binary_accuracy: 0.7724
# Epoch 00100: val_loss improved from 0.52469 to 0.52343, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5173 - binary_accuracy: 0.7746 - val_loss: 0.5234 - val_binary_accuracy: 0.7728
# Epoch 101/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5175 - binary_accuracy: 0.7744
# Epoch 00101: val_loss improved from 0.52343 to 0.52220, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5182 - binary_accuracy: 0.7747 - val_loss: 0.5222 - val_binary_accuracy: 0.7736
# Epoch 102/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5175 - binary_accuracy: 0.7742
# Epoch 00102: val_loss improved from 0.52220 to 0.52099, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5151 - binary_accuracy: 0.7754 - val_loss: 0.5210 - val_binary_accuracy: 0.7736
# Epoch 103/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5146 - binary_accuracy: 0.7780
# Epoch 00103: val_loss improved from 0.52099 to 0.51980, saving model to project.hdf5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5166 - binary_accuracy: 0.7754 - val_loss: 0.5198 - val_binary_accuracy: 0.7740
# Epoch 104/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5144 - binary_accuracy: 0.7757
# Epoch 00104: val_loss improved from 0.51980 to 0.51864, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5138 - binary_accuracy: 0.7759 - val_loss: 0.5186 - val_binary_accuracy: 0.7742
# Epoch 105/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5133 - binary_accuracy: 0.7757
# Epoch 00105: val_loss improved from 0.51864 to 0.51751, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5126 - binary_accuracy: 0.7763 - val_loss: 0.5175 - val_binary_accuracy: 0.7748
# Epoch 106/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5130 - binary_accuracy: 0.7770
# Epoch 00106: val_loss improved from 0.51751 to 0.51640, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5102 - binary_accuracy: 0.7770 - val_loss: 0.5164 - val_binary_accuracy: 0.7756
# Epoch 107/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5110 - binary_accuracy: 0.7773
# Epoch 00107: val_loss improved from 0.51640 to 0.51534, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5104 - binary_accuracy: 0.7773 - val_loss: 0.5153 - val_binary_accuracy: 0.7766
# Epoch 108/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5098 - binary_accuracy: 0.7785
# Epoch 00108: val_loss improved from 0.51534 to 0.51431, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5096 - binary_accuracy: 0.7775 - val_loss: 0.5143 - val_binary_accuracy: 0.7772
# Epoch 109/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5073 - binary_accuracy: 0.7781
# Epoch 00109: val_loss improved from 0.51431 to 0.51331, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5108 - binary_accuracy: 0.7779 - val_loss: 0.5133 - val_binary_accuracy: 0.7774
# Epoch 110/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5067 - binary_accuracy: 0.7778
# Epoch 00110: val_loss improved from 0.51331 to 0.51233, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5091 - binary_accuracy: 0.7785 - val_loss: 0.5123 - val_binary_accuracy: 0.7778
# Epoch 111/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5066 - binary_accuracy: 0.7806
# Epoch 00111: val_loss improved from 0.51233 to 0.51137, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5066 - binary_accuracy: 0.7787 - val_loss: 0.5114 - val_binary_accuracy: 0.7788
# Epoch 112/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5045 - binary_accuracy: 0.7800
# Epoch 00112: val_loss improved from 0.51137 to 0.51042, saving model to project.hdf5
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5074 - binary_accuracy: 0.7788 - val_loss: 0.5104 - val_binary_accuracy: 0.7798
# Epoch 113/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5041 - binary_accuracy: 0.7785
# Epoch 00113: val_loss improved from 0.51042 to 0.50948, saving model to project.hdf5
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5056 - binary_accuracy: 0.7788 - val_loss: 0.5095 - val_binary_accuracy: 0.7802
# Epoch 114/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5053 - binary_accuracy: 0.7772
# Epoch 00114: val_loss improved from 0.50948 to 0.50853, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5012 - binary_accuracy: 0.7792 - val_loss: 0.5085 - val_binary_accuracy: 0.7806
# Epoch 115/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5027 - binary_accuracy: 0.7793
# Epoch 00115: val_loss improved from 0.50853 to 0.50761, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5028 - binary_accuracy: 0.7793 - val_loss: 0.5076 - val_binary_accuracy: 0.7806
# Epoch 116/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5014 - binary_accuracy: 0.7813
# Epoch 00116: val_loss improved from 0.50761 to 0.50671, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5026 - binary_accuracy: 0.7797 - val_loss: 0.5067 - val_binary_accuracy: 0.7804
# Epoch 117/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5001 - binary_accuracy: 0.7813
# Epoch 00117: val_loss improved from 0.50671 to 0.50583, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5023 - binary_accuracy: 0.7798 - val_loss: 0.5058 - val_binary_accuracy: 0.7813
# Epoch 118/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5004 - binary_accuracy: 0.7796
# Epoch 00118: val_loss improved from 0.50583 to 0.50497, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4997 - binary_accuracy: 0.7800 - val_loss: 0.5050 - val_binary_accuracy: 0.7821
# Epoch 119/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4986 - binary_accuracy: 0.7806
# Epoch 00119: val_loss improved from 0.50497 to 0.50412, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5003 - binary_accuracy: 0.7803 - val_loss: 0.5041 - val_binary_accuracy: 0.7831
# Epoch 120/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4997 - binary_accuracy: 0.7784
# Epoch 00120: val_loss improved from 0.50412 to 0.50329, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4963 - binary_accuracy: 0.7805 - val_loss: 0.5033 - val_binary_accuracy: 0.7825
# Epoch 121/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4958 - binary_accuracy: 0.7840
# Epoch 00121: val_loss improved from 0.50329 to 0.50249, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5003 - binary_accuracy: 0.7809 - val_loss: 0.5025 - val_binary_accuracy: 0.7823
# Epoch 122/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4986 - binary_accuracy: 0.7789
# Epoch 00122: val_loss improved from 0.50249 to 0.50172, saving model to project.hdf5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4938 - binary_accuracy: 0.7814 - val_loss: 0.5017 - val_binary_accuracy: 0.7823
# Epoch 123/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4982 - binary_accuracy: 0.7797
# Epoch 00123: val_loss improved from 0.50172 to 0.50097, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4925 - binary_accuracy: 0.7814 - val_loss: 0.5010 - val_binary_accuracy: 0.7825
# Epoch 124/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4953 - binary_accuracy: 0.7813
# Epoch 00124: val_loss improved from 0.50097 to 0.50022, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4950 - binary_accuracy: 0.7813 - val_loss: 0.5002 - val_binary_accuracy: 0.7821
# Epoch 125/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4945 - binary_accuracy: 0.7801
# Epoch 00125: val_loss improved from 0.50022 to 0.49946, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4943 - binary_accuracy: 0.7815 - val_loss: 0.4995 - val_binary_accuracy: 0.7829
# Epoch 126/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4939 - binary_accuracy: 0.7813
# Epoch 00126: val_loss improved from 0.49946 to 0.49871, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4933 - binary_accuracy: 0.7820 - val_loss: 0.4987 - val_binary_accuracy: 0.7835
# Epoch 127/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4922 - binary_accuracy: 0.7831
# Epoch 00127: val_loss improved from 0.49871 to 0.49799, saving model to project.hdf5
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4941 - binary_accuracy: 0.7825 - val_loss: 0.4980 - val_binary_accuracy: 0.7833
# Epoch 128/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4926 - binary_accuracy: 0.7831
# Epoch 00128: val_loss improved from 0.49799 to 0.49727, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4916 - binary_accuracy: 0.7828 - val_loss: 0.4973 - val_binary_accuracy: 0.7837
# Epoch 129/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4917 - binary_accuracy: 0.7829
# Epoch 00129: val_loss improved from 0.49727 to 0.49656, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4913 - binary_accuracy: 0.7829 - val_loss: 0.4966 - val_binary_accuracy: 0.7837
# Epoch 130/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4915 - binary_accuracy: 0.7822
# Epoch 00130: val_loss improved from 0.49656 to 0.49587, saving model to project.hdf5
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4898 - binary_accuracy: 0.7828 - val_loss: 0.4959 - val_binary_accuracy: 0.7839
# Epoch 131/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4909 - binary_accuracy: 0.7823
# Epoch 00131: val_loss improved from 0.49587 to 0.49519, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4890 - binary_accuracy: 0.7833 - val_loss: 0.4952 - val_binary_accuracy: 0.7833
# Epoch 132/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4898 - binary_accuracy: 0.7837
# Epoch 00132: val_loss improved from 0.49519 to 0.49452, saving model to project.hdf5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4889 - binary_accuracy: 0.7835 - val_loss: 0.4945 - val_binary_accuracy: 0.7837
# Epoch 133/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4897 - binary_accuracy: 0.7837
# Epoch 00133: val_loss improved from 0.49452 to 0.49386, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4874 - binary_accuracy: 0.7837 - val_loss: 0.4939 - val_binary_accuracy: 0.7833
# Epoch 134/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4867 - binary_accuracy: 0.7859
# Epoch 00134: val_loss improved from 0.49386 to 0.49323, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4905 - binary_accuracy: 0.7839 - val_loss: 0.4932 - val_binary_accuracy: 0.7833
# Epoch 135/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4863 - binary_accuracy: 0.7850
# Epoch 00135: val_loss improved from 0.49323 to 0.49263, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4895 - binary_accuracy: 0.7840 - val_loss: 0.4926 - val_binary_accuracy: 0.7837
# Epoch 136/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4857 - binary_accuracy: 0.7860
# Epoch 00136: val_loss improved from 0.49263 to 0.49205, saving model to project.hdf5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4888 - binary_accuracy: 0.7841 - val_loss: 0.4920 - val_binary_accuracy: 0.7835
# Epoch 137/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4858 - binary_accuracy: 0.7852
# Epoch 00137: val_loss improved from 0.49205 to 0.49147, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4872 - binary_accuracy: 0.7844 - val_loss: 0.4915 - val_binary_accuracy: 0.7831
# Epoch 138/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4840 - binary_accuracy: 0.7870
# Epoch 00138: val_loss improved from 0.49147 to 0.49092, saving model to project.hdf5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4884 - binary_accuracy: 0.7845 - val_loss: 0.4909 - val_binary_accuracy: 0.7845
# Epoch 139/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4847 - binary_accuracy: 0.7851
# Epoch 00139: val_loss improved from 0.49092 to 0.49037, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4859 - binary_accuracy: 0.7851 - val_loss: 0.4904 - val_binary_accuracy: 0.7845
# Epoch 140/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4836 - binary_accuracy: 0.7860
# Epoch 00140: val_loss improved from 0.49037 to 0.48983, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4863 - binary_accuracy: 0.7851 - val_loss: 0.4898 - val_binary_accuracy: 0.7847
# Epoch 141/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4827 - binary_accuracy: 0.7874
# Epoch 00141: val_loss improved from 0.48983 to 0.48930, saving model to project.hdf5
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4861 - binary_accuracy: 0.7850 - val_loss: 0.4893 - val_binary_accuracy: 0.7851
# Epoch 142/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4845 - binary_accuracy: 0.7853
# Epoch 00142: val_loss improved from 0.48930 to 0.48878, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4819 - binary_accuracy: 0.7857 - val_loss: 0.4888 - val_binary_accuracy: 0.7855
# Epoch 143/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4833 - binary_accuracy: 0.7852
# Epoch 00143: val_loss improved from 0.48878 to 0.48827, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4825 - binary_accuracy: 0.7855 - val_loss: 0.4883 - val_binary_accuracy: 0.7855
# Epoch 144/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4837 - binary_accuracy: 0.7850
# Epoch 00144: val_loss improved from 0.48827 to 0.48777, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4805 - binary_accuracy: 0.7858 - val_loss: 0.4878 - val_binary_accuracy: 0.7849
# Epoch 145/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4834 - binary_accuracy: 0.7840
# Epoch 00145: val_loss improved from 0.48777 to 0.48727, saving model to project.hdf5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4796 - binary_accuracy: 0.7859 - val_loss: 0.4873 - val_binary_accuracy: 0.7847
# Epoch 146/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4797 - binary_accuracy: 0.7886
# Epoch 00146: val_loss improved from 0.48727 to 0.48678, saving model to project.hdf5
# ...
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4321 - binary_accuracy: 0.8024 - val_loss: 0.4522 - val_binary_accuracy: 0.7889
# Epoch 609/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4301 - binary_accuracy: 0.8047
# Epoch 00609: val_loss improved from 0.45217 to 0.45217, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4369 - binary_accuracy: 0.8024 - val_loss: 0.4522 - val_binary_accuracy: 0.7887
# Epoch 610/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4335 - binary_accuracy: 0.8001
# Epoch 00610: val_loss improved from 0.45217 to 0.45216, saving model to project.hdf5
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4315 - binary_accuracy: 0.8022 - val_loss: 0.4522 - val_binary_accuracy: 0.7887
# Epoch 611/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4335 - binary_accuracy: 0.8027
# Epoch 00611: val_loss improved from 0.45216 to 0.45215, saving model to project.hdf5
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4314 - binary_accuracy: 0.8023 - val_loss: 0.4522 - val_binary_accuracy: 0.7891
# Epoch 612/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4309 - binary_accuracy: 0.8035
# Epoch 00612: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4353 - binary_accuracy: 0.8022 - val_loss: 0.4522 - val_binary_accuracy: 0.7897
# Epoch 613/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4301 - binary_accuracy: 0.8040
# Epoch 00613: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4365 - binary_accuracy: 0.8022 - val_loss: 0.4522 - val_binary_accuracy: 0.7897
# Epoch 614/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4335 - binary_accuracy: 0.8022
# Epoch 00614: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4311 - binary_accuracy: 0.8024 - val_loss: 0.4522 - val_binary_accuracy: 0.7901
# Epoch 615/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4354 - binary_accuracy: 0.8015
# Epoch 00615: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4279 - binary_accuracy: 0.8024 - val_loss: 0.4522 - val_binary_accuracy: 0.7901
# Epoch 616/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4332 - binary_accuracy: 0.8027
# Epoch 00616: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4313 - binary_accuracy: 0.8028 - val_loss: 0.4523 - val_binary_accuracy: 0.7905
# Epoch 617/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4330 - binary_accuracy: 0.8025
# Epoch 00617: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4314 - binary_accuracy: 0.8028 - val_loss: 0.4523 - val_binary_accuracy: 0.7901
# Epoch 618/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4329 - binary_accuracy: 0.8013
# Epoch 00618: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4314 - binary_accuracy: 0.8028 - val_loss: 0.4523 - val_binary_accuracy: 0.7901
# Epoch 619/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4315 - binary_accuracy: 0.8031
# Epoch 00619: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4334 - binary_accuracy: 0.8028 - val_loss: 0.4523 - val_binary_accuracy: 0.7901
# Epoch 620/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4334 - binary_accuracy: 0.8022
# Epoch 00620: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4304 - binary_accuracy: 0.8030 - val_loss: 0.4523 - val_binary_accuracy: 0.7889
# Epoch 621/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4326 - binary_accuracy: 0.8030
# Epoch 00621: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4315 - binary_accuracy: 0.8030 - val_loss: 0.4523 - val_binary_accuracy: 0.7883
# Epoch 622/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4344 - binary_accuracy: 0.8015
# Epoch 00622: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4285 - binary_accuracy: 0.8029 - val_loss: 0.4523 - val_binary_accuracy: 0.7885
# Epoch 623/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4307 - binary_accuracy: 0.8026
# Epoch 00623: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4342 - binary_accuracy: 0.8028 - val_loss: 0.4523 - val_binary_accuracy: 0.7879
# Epoch 624/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4298 - binary_accuracy: 0.8040
# Epoch 00624: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4356 - binary_accuracy: 0.8029 - val_loss: 0.4524 - val_binary_accuracy: 0.7871
# Epoch 625/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4306 - binary_accuracy: 0.8041
# Epoch 00625: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4341 - binary_accuracy: 0.8030 - val_loss: 0.4524 - val_binary_accuracy: 0.7869
# Epoch 626/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4328 - binary_accuracy: 0.8024
# Epoch 00626: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4306 - binary_accuracy: 0.8030 - val_loss: 0.4524 - val_binary_accuracy: 0.7865
# Epoch 627/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4318 - binary_accuracy: 0.8030
# Epoch 00627: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4321 - binary_accuracy: 0.8028 - val_loss: 0.4524 - val_binary_accuracy: 0.7867
# Epoch 628/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4318 - binary_accuracy: 0.8041
# Epoch 00628: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4319 - binary_accuracy: 0.8029 - val_loss: 0.4525 - val_binary_accuracy: 0.7867
# Epoch 629/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4329 - binary_accuracy: 0.8028
# Epoch 00629: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4301 - binary_accuracy: 0.8031 - val_loss: 0.4525 - val_binary_accuracy: 0.7869
# Epoch 630/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4316 - binary_accuracy: 0.8028
# Epoch 00630: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4320 - binary_accuracy: 0.8031 - val_loss: 0.4525 - val_binary_accuracy: 0.7863
# Epoch 631/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4327 - binary_accuracy: 0.8031
# Epoch 00631: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4301 - binary_accuracy: 0.8032 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 632/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4341 - binary_accuracy: 0.8018
# Epoch 00632: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4279 - binary_accuracy: 0.8035 - val_loss: 0.4526 - val_binary_accuracy: 0.7859
# Epoch 633/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4322 - binary_accuracy: 0.8033
# Epoch 00633: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4307 - binary_accuracy: 0.8035 - val_loss: 0.4526 - val_binary_accuracy: 0.7863
# Epoch 634/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4322 - binary_accuracy: 0.8036
# Epoch 00634: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4306 - binary_accuracy: 0.8034 - val_loss: 0.4526 - val_binary_accuracy: 0.7865
# Epoch 635/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4319 - binary_accuracy: 0.8023
# Epoch 00635: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4309 - binary_accuracy: 0.8034 - val_loss: 0.4526 - val_binary_accuracy: 0.7861
# Epoch 636/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4310 - binary_accuracy: 0.8052
# Epoch 00636: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4323 - binary_accuracy: 0.8033 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 637/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4311 - binary_accuracy: 0.8034
# Epoch 00637: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4318 - binary_accuracy: 0.8034 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 638/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4294 - binary_accuracy: 0.8041
# Epoch 00638: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4344 - binary_accuracy: 0.8032 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 639/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4328 - binary_accuracy: 0.8037
# Epoch 00639: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4290 - binary_accuracy: 0.8030 - val_loss: 0.4525 - val_binary_accuracy: 0.7867
# Epoch 640/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4282 - binary_accuracy: 0.8042
# Epoch 00640: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4360 - binary_accuracy: 0.8029 - val_loss: 0.4525 - val_binary_accuracy: 0.7869
# Epoch 641/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4294 - binary_accuracy: 0.8049
# Epoch 00641: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4340 - binary_accuracy: 0.8029 - val_loss: 0.4525 - val_binary_accuracy: 0.7873
# Epoch 642/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4299 - binary_accuracy: 0.8037
# Epoch 00642: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4332 - binary_accuracy: 0.8029 - val_loss: 0.4525 - val_binary_accuracy: 0.7881
# Epoch 643/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4321 - binary_accuracy: 0.8037
# Epoch 00643: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4296 - binary_accuracy: 0.8031 - val_loss: 0.4526 - val_binary_accuracy: 0.7887
# Epoch 644/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4298 - binary_accuracy: 0.8027
# Epoch 00644: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4331 - binary_accuracy: 0.8031 - val_loss: 0.4526 - val_binary_accuracy: 0.7891
# Epoch 645/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4319 - binary_accuracy: 0.8013
# Epoch 00645: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4296 - binary_accuracy: 0.8029 - val_loss: 0.4526 - val_binary_accuracy: 0.7893
# Epoch 646/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4305 - binary_accuracy: 0.8036
# Epoch 00646: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4318 - binary_accuracy: 0.8029 - val_loss: 0.4526 - val_binary_accuracy: 0.7893
# Epoch 647/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4322 - binary_accuracy: 0.8017
# Epoch 00647: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4289 - binary_accuracy: 0.8028 - val_loss: 0.4526 - val_binary_accuracy: 0.7885
# Epoch 648/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4313 - binary_accuracy: 0.8032
# Epoch 00648: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4303 - binary_accuracy: 0.8030 - val_loss: 0.4526 - val_binary_accuracy: 0.7879
# Epoch 649/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4305 - binary_accuracy: 0.8025
# Epoch 00649: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4314 - binary_accuracy: 0.8029 - val_loss: 0.4526 - val_binary_accuracy: 0.7883
# Epoch 650/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4316 - binary_accuracy: 0.8025
# Epoch 00650: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4295 - binary_accuracy: 0.8029 - val_loss: 0.4526 - val_binary_accuracy: 0.7877
# Epoch 651/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4317 - binary_accuracy: 0.8030
# Epoch 00651: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4293 - binary_accuracy: 0.8030 - val_loss: 0.4526 - val_binary_accuracy: 0.7871
# Epoch 652/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4289 - binary_accuracy: 0.8037
# Epoch 00652: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4335 - binary_accuracy: 0.8030 - val_loss: 0.4526 - val_binary_accuracy: 0.7871
# Epoch 653/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4297 - binary_accuracy: 0.8035
# Epoch 00653: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4322 - binary_accuracy: 0.8031 - val_loss: 0.4526 - val_binary_accuracy: 0.7869
# Epoch 654/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4330 - binary_accuracy: 0.8018
# Epoch 00654: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4269 - binary_accuracy: 0.8032 - val_loss: 0.4525 - val_binary_accuracy: 0.7867
# Epoch 655/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4305 - binary_accuracy: 0.8034
# Epoch 00655: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4307 - binary_accuracy: 0.8032 - val_loss: 0.4525 - val_binary_accuracy: 0.7863
# Epoch 656/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4309 - binary_accuracy: 0.8040
# Epoch 00656: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4300 - binary_accuracy: 0.8031 - val_loss: 0.4525 - val_binary_accuracy: 0.7863
# Epoch 657/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4303 - binary_accuracy: 0.8045
# Epoch 00657: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4307 - binary_accuracy: 0.8030 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 658/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4317 - binary_accuracy: 0.8024
# Epoch 00658: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4285 - binary_accuracy: 0.8030 - val_loss: 0.4525 - val_binary_accuracy: 0.7857
# Epoch 659/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4305 - binary_accuracy: 0.8038
# Epoch 00659: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4301 - binary_accuracy: 0.8030 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 660/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4290 - binary_accuracy: 0.8033
# Epoch 00660: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4323 - binary_accuracy: 0.8029 - val_loss: 0.4525 - val_binary_accuracy: 0.7859
# Epoch 661/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4307 - binary_accuracy: 0.8019
# Epoch 00661: val_loss did not improve from 0.45215
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4296 - binary_accuracy: 0.8030 - val_loss: 0.4525 - val_binary_accuracy: 0.7861
# Epoch 00661: early stopping

# %%
# Do the training (specify the validation set as well)
#history = model.fit(XTRAIN, YTRAIN, epochs=100, batch_size= 50, verbose=0) #, validation_data=(XVALID, YVALID)

model.load_weights('project.hdf5')

# Check what's in the history
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
print(history.params)
# Plot the learning curves (loss/accuracy/MAE)
plt.plot(history.history['loss']) # replace with accuracy/MAE
plt.plot(history.history['val_loss']) # replace with val_accuracy, etc.
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='upper right')
plt.show()
# Plot the learning curves (loss/accuracy/MAE)
plt.plot(history.history['binary_accuracy']) # replace with accuracy/MAE
plt.plot(history.history['val_binary_accuracy']) # replace with val_accuracy, etc.
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['training data', 'validation data'], loc='lower right')
plt2.show()
model.summary()
# Out:
# {'verbose': 1, 'epochs': 1000, 'steps': 2}
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                4050
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 4,061
# Trainable params: 4,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
np.set_printoptions(precision = 2)

prediction = model.predict(XVALID)
prediction = np.round(np.clip(model.predict(XVALID), 0, 1)) # binary

Validation_Accuracy = accuracy_score(YVALID, prediction.round())
Validation_Precision = precision_score(YVALID, prediction.round())
Validation_Recall = recall_score(YVALID, prediction.round())
Validation_F1score = f1_score(YVALID, prediction.round())

print("Validation Accuracy: %.2f%%" % (Validation_Accuracy * 100.0))
print("Validation Precision: %.2f%%" % (Validation_Precision * 100.0))
print("Validation Recall: %.2f%%" % (Validation_Recall * 100.0))
print("Validation F1-score: %.2f" % (Validation_F1score))
print()
result = (100*Validation_Accuracy)-ratio
print("Model's predicted outcome rated against assuming \n"
+ "non-intoxicated involvment for all cases of %.2f%%"  %result +" points.")
# Out:
# Validation Accuracy: 78.91%
# Validation Precision: 61.46%
# Validation Recall: 39.68%
# Validation F1-score: 0.48
#
# Model's predicted outcome rated against assuming
# non-intoxicated involvment for all cases of 3.80% points.

# %% [markdown]
# **Summary of the Testing**
#
# I ran this same model for 1000 iteration without using the early stop. It had a Validation Accuracy of 78.13% after 1000 epochs, after 2,000 epochs it's Validation Accuracy had dropped even further to 76.37%. Stop early proved to be stopped at 661 using a patience of 50 and had Validation Accuracy of 78.91%.
